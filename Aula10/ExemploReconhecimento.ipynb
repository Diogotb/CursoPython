# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2

#py -m pip install tensorflow

# %%
# Carregar a imagem
imagem = cv2.imread('imagem_rostos.jpg')

# Carregar o classificador de detecção de faces pré-treinado
classificador_faces = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Converter a imagem para escala de cinza (necessário para detecção de objetos)
imagem_gray = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

# Detectar rostos na imagem
faces = classificador_faces.detectMultiScale(imagem_gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Desenhar retângulos ao redor dos rostos detectados
for (x, y, w, h) in faces:
    cv2.rectangle(imagem, (x, y), (x+w, y+h), (255, 0, 0), 2)

# Exibir a imagem com os rostos detectados
plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))
plt.title('Detecção de Rostos')
plt.axis('off')
plt.show()

# %%
# Carregar o modelo MobileNet pré-treinado
model = tf.keras.applications.MobileNetV2(weights='imagenet')

# Função para carregar e pré-processar uma imagem
def load_and_preprocess_image(image_path):
    # Carregar a imagem
    img = tf.io.read_file(image_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.resize(img, (224, 224))
    img = tf.keras.applications.mobilenet_v2.preprocess_input(img)
    return img

# Função para fazer a predição de objetos em uma imagem
def predict_objects(image_path):
    # Carregar e pré-processar a imagem
    img = load_and_preprocess_image(image_path)
    
    # Adicionar uma dimensão extra para o batch
    img = np.expand_dims(img, axis=0)
    
    # Fazer a predição
    preds = model.predict(img)
    
    # Decodificar as previsões
    decoded_preds = tf.keras.applications.mobilenet_v2.decode_predictions(preds, top=5)[0]
    
    return decoded_preds

# Função para exibir a imagem com os objetos detectados
def display_image_with_objects(image_path, objects):
    # Carregar a imagem
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    # Desenhar caixas ao redor dos objetos detectados
    for _, label, confidence in objects:
        cv2.putText(img, f'{label} ({confidence:.2f})', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    
    # Exibir a imagem
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# Caminho para a imagem que você deseja analisar
image_path = "canecas.jpg"

# Fazer a predição de objetos na imagem
objects = predict_objects(image_path)

# Exibir a imagem com os objetos detectados
display_image_with_objects(image_path, objects)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[5], line 48
#      45 image_path = "canecas.jpg"
#      47 # Fazer a predição de objetos na imagem
# ---> 48 objects = predict_objects(image_path)
#      50 # Exibir a imagem com os objetos detectados
#      51 display_image_with_objects(image_path, objects)
#
# Cell In[5], line 16, in predict_objects(image_path)
#      14 def predict_objects(image_path):
#      15     # Carregar e pré-processar a imagem
# ---> 16     img = load_and_preprocess_image(image_path)
#      18     # Adicionar uma dimensão extra para o batch
#      19     img = np.expand_dims(img, axis=0)
#
# Cell In[5], line 8, in load_and_preprocess_image(image_path)
#       5 def load_and_preprocess_image(image_path):
#       6     # Carregar a imagem
#       7     img = tf.io.read_file(image_path)
# ----> 8     img = tf.image.decode_image(img, channels=3)
#       9     img = tf.image.resize(img, (224, 224))
#      10     img = tf.keras.applications.mobilenet_v2.preprocess_input(img)
#
# File c:\Users\DevTarde\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File c:\Users\DevTarde\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\ops.py:5983, in raise_from_not_ok_status(e, name)
#    5981 def raise_from_not_ok_status(e, name) -> NoReturn:
#    5982   e.message += (" name: " + str(name if name is not None else ""))
# -> 5983   raise core._status_to_exception(e) from None
#
# InvalidArgumentError: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
